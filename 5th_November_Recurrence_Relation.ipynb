# %% [markdown]
# <h1>Recurrence Relation</h1>

# %% [markdown]
# <b>1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.</b><br>
# To find the value of T(2) for the given recurrence relation T(n) = 3T(n-1) + 12n, with T(0) = 5, we can use the recursive nature of the relation to calculate the value.<br>
# Analysis and Comparison of Different Optimizers
# For the given recurrence relation and the calculation of T(2), there are no specific optimizers that can be applied. The calculation is straightforward and does not involve any complex computations or optimizations.<br>
# <pre>
# def calculate_T(n):
#     if n == 0:
#         return 5
#     else:
#         return 3 * calculate_T(n-1) + 12 * n
#
# n = 2
# T_2 = calculate_T(n)
# print(T_2)
# </pre>
# Since the calculation of T(2) is a mathematical operation and does not require code implementation, there is no specific code organization or implementation needed in this case.<br>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 0, where the function returns the initial value T(0) = 5. For any other value of n, the function recursively calls itself with n-1 and performs the necessary calculations.<br>

# %% [markdown]
# <b>2. Given a recurrence relation, solve it using the substitution method:<br>
# a. T(n) = T(n-1) + c<br>
# b. T(n) = 2T(n/2) + n<br>
# c. T(n) = 2T(n/2) + c<br>
# d. T(n) = T(n/2) + c</b><br>
#
# <b>a. T(n) = T(n-1) + c</b><br>
# To solve this recurrence relation using the substitution method, we can implement it in Python as follows:<br>
# <pre>
# def calculate_T(n):
#     if n == 0:
#         return 0
#     else:
#         return calculate_T(n-1) + c
#
# c = 5
# n = 10
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 0, where the function returns 0. For any other value of n, the function recursively calls itself with n-1 and adds the constant c to the result.
#
# By calling calculate_T(n) with the desired value of n, you can find the value of T(n) for the given recurrence relation. The output will be printed as the result.<br>
#
# <b>b. T(n) = 2T(n/2) + n</b><br>
# <pre>
# def calculate_T(n):
#     if n == 1:
#         return 1
#     else:
#         return 2 * calculate_T(n//2) + n
#
# n = 10
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 1, where the function returns 1. For any other value of n, the function recursively calls itself with n//2 (integer division) and multiplies the result by 2, then adds n to the result.
#
# By calling calculate_T(n) with the desired value of n, you can find the value of T(n) for the given recurrence relation. The output will be printed as the result.<br>
#
# <b>c. T(n) = 2T(n/2) + c</b><br>
# <pre>
# def calculate_T(n):
#     if n == 1:
#         return c
#     else:
#         return 2 * calculate_T(n//2) + c
#
# c = 5
# n = 10
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 1, where the function returns the constant c. For any other value of n, the function recursively calls itself with n//2 (integer division) and multiplies the result by 2, then adds the constant c to the result.
#
# By calling calculate_T(n) with the desired value of n, you can find the value of T(n) for the given recurrence relation. The output will be printed as the result.<br>
#
# <b>d. T(n) = T(n/2) + c</b><br>
# <pre>
# def calculate_T(n):
#     if n == 1:
#         return c
#     else:
#         return calculate_T(n//2) + c
#
# c = 5
# n = 10
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 1, where the function returns the constant c. For any other value of n, the function recursively calls itself with n//2 (integer division) and adds the constant c to the result.
#
# By calling calculate_T(n) with the desired value of n, you can find the value of T(n) for the given recurrence relation. The output will be printed as the result<br>

# %% [markdown]
# <b>3. Given a recurrence relation, solve it using the recursive tree approach:<br>
# a. T(n) = 2T(n-1) +1<br>
# b. T(n) = 2T(n/2) + n</b><br>
#
# <b>a. T(n) = 2T(n-1) + 1</b><br>
# <pre>
# def calculate_T(n):
#     if n == 0:
#         return 0
#     else:
#         return 2 * calculate_T(n-1) + 1
#
# n = 5
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 0, where the function returns 0. For any other value of n, the function recursively calls itself with n-1 and multiplies the result by 2, then adds 1 to the result.
#
# By calling calculate_T(n) with the desired value of n, you can find the value of T(n) for the given recurrence relation. The output will be printed as the result.<br>
#
# <b>b. T(n) = 2T(n-1) + n</b><br>
# <pre>
# def calculate_T(n):
#     if n == 1:
#         return 1
#     else:
#         return 2 * calculate_T(n//2) + n
#
# n = 10
# T_n = calculate_T(n)
# print(T_n)
# </pre>
# In this code, the calculate_T function takes an input n and recursively calculates the value of T(n) using the given recurrence relation. The base case is when n is equal to 1, where the function returns 1. For any other value of n, the function recursively calls itself with n//2 (integer division) and multiplies the result by 2, then adds n to the result.<br>
